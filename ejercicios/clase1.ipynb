# %%
# Ejercitación Clase 1

# %% [markdown]
# Para comenzar, importamos la funcionalidad de la librería estándar que nos va a ser necesaria.

# %%
#from urllib import request
from collections import namedtuple
from csv import reader
from pprint import pprint
import bz2
import io

# %% [markdown]
# Obtenemos los datos

# %%
#URL_DATOS = 'nombres_corto.csv.bz2'
URL_DATOS = 'http://datos.gob.ar/dataset/b8418d41-8e0c-4e85-8aa8-80d51a840132/resource/9e1eca6c-4c58-4f22-8bd4-701fa16c9db0/download/nombres-2015.csv'
datos_raw = []

def convertir_linea(linea):
    nombre, cantidad, anio = linea.split(',')
    return (nombre, cantidad, anio)


# obtener los datos de la internets
response = request.urlopen(URL_DATOS)
for linea in response:
    linea = linea.decode('utf-8').strip()
    datos_raw.append(convertir_linea(linea))
#datos_raw = response.read().decode('utf-8')

#with bz2.BZ2File(URL_DATOS, 'rb') as input:
#    with io.TextIOWrapper(input, encoding='utf-8') as dec:        
#        for linea in dec.readlines():
#            datos_raw.append(convertir_linea(linea))
# están en crudo
datos_raw
pprint(datos_raw[:10])
# Out:
# [('Aaraon Nahuel', '4', '2008\n'),
#  ('Aarom Rances', '4', '1999\n'),
#  ('Aaron', '10', '1934\n'),
#  ('Aarón', '10', '1984\n'),
#  ('Aaron', '11', '1981\n'),
#  ('Aaron', '11', '1983\n'),
#  ('Aaron', '113', '2009\n'),
#  ('AARON', '119', '2008\n'),
#  ('Aarón', '13', '1990\n'),
#  ('Aaron', '14', '1931\n')]

# %%
# generar algo que les de forma piola
forma = namedtuple('Registro', 'nombre cantidad anio')

# %%
# generamos nuestra propia lista de registros
datos = []

for lst in datos_raw[1:]:
    datos.append(forma(*lst))
    
#liberamos memoria!
del(datos_raw)

# %%
print(datos[:10])

print(datos[0].nombre)
print(datos[100].cantidad)
print(datos[1000].anio)
# Out:
# [Registro(nombre='Aarom Rances', cantidad='4', anio='1999'), Registro(nombre='Aaron', cantidad='10', anio='1934'), Registro(nombre='Aarón', cantidad='10', anio='1984'), Registro(nombre='Aaron', cantidad='11', anio='1981'), Registro(nombre='Aaron', cantidad='11', anio='1983'), Registro(nombre='Aaron', cantidad='113', anio='2009'), Registro(nombre='AARON', cantidad='119', anio='2008'), Registro(nombre='Aarón', cantidad='13', anio='1990'), Registro(nombre='Aaron', cantidad='14', anio='1931'), Registro(nombre='Aaron', cantidad='14', anio='1988')]
# Aarom Rances
# 14
# 2011

# %%
# consulta existencial
# existe un X tal que X.algo es Y?

for d in datos:
    if d.nombre == 'Carlos' :
        print(d)
# Out:
# Registro(nombre='Carlos', cantidad='10', anio='2015')
# Registro(nombre='Carlos', cantidad='107', anio='1997')
# Registro(nombre='Carlos', cantidad='119', anio='1996')
# Registro(nombre='Carlos', cantidad='123', anio='1926')
# Registro(nombre='Carlos', cantidad='138', anio='1927')
# Registro(nombre='Carlos', cantidad='153', anio='1995')
# Registro(nombre='Carlos', cantidad='154', anio='1928')
# Registro(nombre='Carlos', cantidad='159', anio='1994')
# Registro(nombre='Carlos', cantidad='169', anio='1929')
# Registro(nombre='Carlos', cantidad='208', anio='1993')
# Registro(nombre='Carlos', cantidad='230', anio='1930')
# Registro(nombre='Carlos', cantidad='250', anio='1991')
# Registro(nombre='Carlos', cantidad='25', anio='2009')
# Registro(nombre='Carlos', cantidad='252', anio='1989')
# Registro(nombre='Carlos', cantidad='252', anio='1990')
# Registro(nombre='Carlos', cantidad='26', anio='2011')
# Registro(nombre='Carlos', cantidad='267', anio='1931')
# Registro(nombre='Carlos', cantidad='267', anio='1992')
# Registro(nombre='Carlos', cantidad='27', anio='2010')
# Registro(nombre='Carlos', cantidad='272', anio='1932')
# Registro(nombre='Carlos', cantidad='281', anio='1986')
# Registro(nombre='Carlos', cantidad='28', anio='2008')
# Registro(nombre='Carlos', cantidad='284', anio='1933')
# Registro(nombre='Carlos', cantidad='285', anio='1988')
# Registro(nombre='Carlos', cantidad='29', anio='2007')
# Registro(nombre='Carlos', cantidad='298', anio='1984')
# Registro(nombre='Carlos', cantidad='310', anio='1985')
# Registro(nombre='Carlos', cantidad='310', anio='1987')
# Registro(nombre='Carlos', cantidad='31', anio='2005')
# Registro(nombre='Carlos', cantidad='325', anio='1934')
# Registro(nombre='Carlos', cantidad='328', anio='1982')
# Registro(nombre='Carlos', cantidad='330', anio='1980')
# Registro(nombre='Carlos', cantidad='337', anio='1978')
# Registro(nombre='Carlos', cantidad='339', anio='1983')
# Registro(nombre='Carlos', cantidad='341', anio='1981')
# Registro(nombre='Carlos', cantidad='345', anio='1976')
# Registro(nombre='Carlos', cantidad='363', anio='1975')
# Registro(nombre='Carlos', cantidad='364', anio='1974')
# Registro(nombre='Carlos', cantidad='365', anio='1979')
# Registro(nombre='Carlos', cantidad='37', anio='2013')
# Registro(nombre='Carlos', cantidad='377', anio='1977')
# Registro(nombre='Carlos', cantidad='38', anio='2012')
# Registro(nombre='Carlos', cantidad='388', anio='1971')
# Registro(nombre='Carlos', cantidad='388', anio='1972')
# Registro(nombre='Carlos', cantidad='416', anio='1935')
# Registro(nombre='Carlos', cantidad='417', anio='1936')
# Registro(nombre='Carlos', cantidad='42', anio='2006')
# Registro(nombre='Carlos', cantidad='428', anio='1968')
# Registro(nombre='Carlos', cantidad='430', anio='1973')
# Registro(nombre='Carlos', cantidad='43', anio='2014')
# Registro(nombre='Carlos', cantidad='432', anio='1969')
# Registro(nombre='Carlos', cantidad='438', anio='1967')
# Registro(nombre='Carlos', cantidad='478', anio='1970')
# Registro(nombre='Carlos', cantidad='492', anio='1937')
# Registro(nombre='Carlos', cantidad='499', anio='1938')
# Registro(nombre='Carlos', cantidad='50', anio='2003')
# Registro(nombre='Carlos', cantidad='508', anio='1965')
# Registro(nombre='Carlos', cantidad='510', anio='1966')
# Registro(nombre='Carlos', cantidad='52', anio='2001')
# Registro(nombre='Carlos', cantidad='536', anio='1964')
# Registro(nombre='Carlos', cantidad='541', anio='1963')
# Registro(nombre='Carlos', cantidad='54', anio='1922')
# Registro(nombre='Carlos', cantidad='564', anio='1939')
# Registro(nombre='Carlos', cantidad='57', anio='1923')
# Registro(nombre='Carlos', cantidad='572', anio='1961')
# Registro(nombre='Carlos', cantidad='590', anio='1941')
# Registro(nombre='Carlos', cantidad='61', anio='2000')
# Registro(nombre='Carlos', cantidad='61', anio='2002')
# Registro(nombre='Carlos', cantidad='62', anio='2004')
# Registro(nombre='Carlos', cantidad='622', anio='1962')
# Registro(nombre='Carlos', cantidad='642', anio='1960')
# Registro(nombre='Carlos', cantidad='649', anio='1940')
# Registro(nombre='Carlos', cantidad='653', anio='1942')
# Registro(nombre='Carlos', cantidad='673', anio='1958')
# Registro(nombre='Carlos', cantidad='68', anio='1999')
# Registro(nombre='Carlos', cantidad='684', anio='1959')
# Registro(nombre='Carlos', cantidad='693', anio='1957')
# Registro(nombre='Carlos', cantidad='719', anio='1955')
# Registro(nombre='Carlos', cantidad='75', anio='1924')
# Registro(nombre='Carlos', cantidad='75', anio='1998')
# Registro(nombre='Carlos', cantidad='769', anio='1956')
# Registro(nombre='Carlos', cantidad='771', anio='1945')
# Registro(nombre='Carlos', cantidad='776', anio='1952')
# Registro(nombre='Carlos', cantidad='781', anio='1944')
# Registro(nombre='Carlos', cantidad='782', anio='1948')
# Registro(nombre='Carlos', cantidad='785', anio='1954')
# Registro(nombre='Carlos', cantidad='787', anio='1949')
# Registro(nombre='Carlos', cantidad='807', anio='1946')
# Registro(nombre='Carlos', cantidad='808', anio='1947')
# Registro(nombre='Carlos', cantidad='823', anio='1950')
# Registro(nombre='Carlos', cantidad='850', anio='1951')
# Registro(nombre='Carlos', cantidad='92', anio='1925')

# %%
#consulta por cantidad
# cuantos X cumplen X.algo=Y? (COUNT)

r = []
for d in datos:
    if d.nombre =='Carlos' and d.anio > '1960' :
        r.append(d)
print ('{} registros'.format(len(r)))
# Out:
# 55 registros

# %%
#sumar todos los blah de los X, con blah mayor que blip (SUM)
r = []
for d in datos:
    if d.nombre == 'Carlos' :
        r.append(int(d.cantidad))
print("Se registraron {} Carlos".format(sum(r)))
# Out:
# Se registraron 32446 Carlos

# %%
def cantidad_de(nombre):
    r = []
    for d in datos:
        if d.nombre == nombre:
            r.append(int(d.cantidad))
    return sum(r)

def hay_mas_que(nombre1, nombre2):
    return cantidad_de(nombre1) > cantidad_de(nombre2)

if hay_mas_que('Juan', 'Maria'):
    print("Hay más Juanes que Marías")
else:
    print("No hay más Juanes que Marías")
# Out:
# No hay más Juanes que Marías

# %%
def promedio(lst):
    if lst:
        return sum(lst) / len(lst)
    else:
        return 0

#sumar todos los blah de los X, con blah mayor que blip (SUM)
r = []
nombre = 'Carlos'
for d in datos:
    if d.nombre == nombre :
        r.append(int(d.cantidad))
print('Hubo un promedio de {} {} por año'.format(promedio(r), nombre))
# Out:
# Hubo un promedio de 352.67391304347825 Carlos por año

# %%
#agrupar los nombres por longitud (GROUPBY)
from collections import defaultdict

nombres_por_longitud = defaultdict(list)
for d in datos:
    nombres_por_longitud[len(d.nombre)].append(d.nombre)
print(nombres_por_longitud.keys())
print(nombres_por_longitud[100])
# Out:
# dict_keys([12, 5, 100, 10, 13, 11, 15, 25, 9, 14, 19, 21, 18, 17, 26, 20, 16, 54, 23, 22, 7, 4, 6, 8, 3, 27, 43, 24, 29, 37, 31, 28, 34, 96, 99, 33, 30, 98, 83, 36, 38, 88, 41, 92, 32, 94, 97, 78, 35, 95, 75, 66, 2, 76, 50, 84, 93, 70, 90, 91, 89, 67, 85, 86, 65, 77, 82, 40, 87, 60, 47, 73, 80, 74, 39, 44, 45, 42, 79])
# ['Aarón                                                                                               ', 'Aaron Alejandro                                                                                     ', 'Aaron Israel                                                                                        ', 'Abel Agustín                                                                                        ', 'Abel Alfredo                                                                                        ', 'Abel David                                                                                          ', 'Abel Gustavo                                                                                        ', 'Abel Jesus                                                                                          ', 'Abel Leonardo                                                                                       ', 'Abel Matias                                                                                         ', 'Abel Nicolas                                                                                        ', 'Abhay Charan                                                                                        ', 'Abigail Anabela                                                                                     ', 'Abigail Antonella                                                                                   ', 'Abigail Ayelen                                                                                      ', 'Abigail Carina                                                                                      ', 'Abigail Carolina                                                                                    ', 'Abigail Magalí                                                                                      ', 'Abigail Magdalena                                                                                   ', 'Abigail Maria De Los Angeles                                                                        ', 'Abigail Marianela                                                                                   ', 'Abigail Marisol                                                                                     ', 'Abigail Naara                                                                                       ', 'Abigail Oriana                                                                                      ', 'Abigail Priscila                                                                                    ', 'Abigail Rocio                                                                                       ', 'Abigail Victoria                                                                                    ', 'Abigail Yanina                                                                                      ', 'Abraham Alejandro                                                                                   ', 'Abril Celeste                                                                                       ', 'Abril Constanza                                                                                     ', 'Abril Daiana                                                                                        ', 'Abril Melina                                                                                        ', 'Abril Milagros                                                                                      ', 'Abril Natalia                                                                                       ', 'Abril Nicole                                                                                        ', 'Abril Soledad                                                                                       ', 'Abril Soledad                                                                                       ', 'Abril Tamara                                   ...

# %%
#dame los 10 nombres más comunes
r = defaultdict(int)
for d in datos:
    try:
        r[d.nombre] += int(d.cantidad)
    except:
        print(d)
items = []
for k, v in r.items():
    items.append((k,v))
items = sorted(items, key=lambda t:t[1], reverse=True)
print(items[:10])
# Out:
# [('Juan Carlos', 288532), ('Miguel Angel', 252514), ('Carlos Alberto', 190284), ('Jose Luis', 168774), ('Ana Maria', 150638), ('Maria Cristina', 124121), ('Luis Alberto', 123746), ('Juan Manuel', 111369), ('Juan Pablo', 93757), ('Juan Jose', 86081)]
