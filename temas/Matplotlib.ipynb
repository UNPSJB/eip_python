# %% [markdown]
# # Grafiquitos lindos con Matplotlib

# %% [markdown]
# `matplotlib` es un paquete para graficar datos de un montón de maneras. Vamos a ver muy por encima algunas maneras de hacer gráficos para nuestros datos.
#
# Para obtener `matplotlib` hacemos
#
# `pip install matplotlib`    o bien
#
# `conda install matplotlib` (si ya no está instalado).

# %%
import matplotlib.pyplot as plt
plt.plot(range(5))
plt.ylabel('Numeritos')
plt.show()

from math import sin

l = []
step = 0.1
x = 0
for i in range(62):
    l.append(sin(x))
    x += step

g

# %% [markdown]
# Ahora en vez de línea azul, puntitos rojos

# %%
plt.plot(l, 'ro')
plt.ylabel('Seno X')
plt.show()

# %% [markdown]
# Ahora cambiamos el eje de las y

# %%
# ambas listas tienen que tener la misma longitud
plt.plot(range(62,0, -1), range(0,124,2))
plt.ylabel('Aburrimiento')
plt.xlabel('Tiempo')
plt.show()

# %%
plt.plot(range(62,0, -1), range(0,124,2), label='Con Python')
plt.plot(range(62), range(0,124,2), label='Sin Python')
plt.ylabel('Aburrimiento')
plt.xlabel('Tiempo')
plt.legend(loc='upper center')
plt.show()
